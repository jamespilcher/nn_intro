# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
a = np.array([
    [1,0],
    [2,3]])
print(a)
# Out:
# [[1 0]
#  [2 3]]

# %%
b = np.array([
    [1,4],d
    [5,6]
])
print(b)
# Out:
# [[1 4]
#  [5 6]]

# %%
ans = np.linalg.inv(a)
print(ans)
# Out:
# [[ 1.          0.        ]
#  [-0.66666667  0.33333333]]

# %%
img = mpimg.imread("dogphotos/dog.jpg")
img2 = mpimg.imread("dogphotos/dog2.jpg")
minus = np.subtract(img,img2)
add = np.add(img,img2)

# %%
imgplot = plt.imshow(minus)

# %%
imgplot = plt.imshow(add)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 img.thumbnail((64, 64), Image.ANTIALIAS)
#       2 imgplot = plt.imshow(img, interpolation="bicubic")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'thumbnail'

# %%
country = ["uk","germany","france"]
gdp = [1000, 1200, 400]

plt.bar(country,gdp)
plt.title('gpd per country')
plt.xlabel('country')
plt.ylabel('gdp')
plt.show()
