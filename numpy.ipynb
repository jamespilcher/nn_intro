# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
a = np.array([
    [1,0],
    [2,3]])
a
# Out:
# array([[1, 0],
#        [2, 3]])

# %%
b = np.array([
    [1,4],
    [5,6]
])
print(b)
# Out:
# [[1 4]
#  [5 6]]

# %%
ans = np.linalg.inv(a)
print(ans)
# Out:
# [[ 1.          0.        ]
#  [-0.66666667  0.33333333]]

# %%
img = mpimg.imread("trafficphotos/trafficA.png")
img2 = mpimg.imread("trafficphotos/trafficB.png")
np.delete(img, 3)
np.delete(img2, 3)

minus = np.subtract(img2,img)
add = np.add(img,img2)
plt.figure(figsize=(12,6))

#imgplot = plt.imshow(minus)

result = np.absolute(minus)

imgplot = plt.imshow(minus + 1)

img[0,0,3]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1.0

# %%
plt.figure(figsize=(12,6))
imgplot = plt.imshow(img)

# %%
plt.figure(figsize=(12,6))
imgplot = plt.imshow(img2)

# %%
plt.figure(figsize=(20,10))
imgplot = plt.imshow(add)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
country = ["uk","germany","france"]
gdp = [1000, 1200, 400]

plt.bar(country,gdp)
plt.title('gpd per country')
plt.xlabel('country')
plt.ylabel('gdp')
plt.show()
